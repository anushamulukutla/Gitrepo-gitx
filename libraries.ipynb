# %% [markdown]
# <a href="https://colab.research.google.com/github/anushamulukutla/Gitrepo-gitx/blob/master/libraries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot
v1=[5,2,9,4,7]
v2=[10,5,8,4,2]
pyplot.xlabel("x-axis")
pyplot.ylabel("y-axis")
pyplot.plot(v2,v1)
pyplot.show()

# %%
# bar_chart.py

import matplotlib.pyplot as plt

def bar_chart(numbers, labels, pos):
    plt.bar(pos, numbers, color='blue')
    plt.xticks(ticks=pos, labels=labels)
    plt.show()

if __name__ == '__main__':
    numbers = [2, 1, 4, 6]
    labels = ['Electric', 'Solar', 'Diesel', 'Unleaded']
    pos = list(range(4))
    bar_chart(numbers, labels, pos)


    """
Activity 1:
Create a barchart that displays the popularity of different programming languages. Example: Python, C++, Ruby, Java
Display labels for both axis and display a chart title
Challenge: Change the color of each bar.
"""

    """

# %%
#ANUSHA

import matplotlib.pyplot as plt

Popularity = [100, 70, 40, 67]
lang= ['Python', 'C', 'C++', 'SQL']
bars = plt.bar(lang,Popularity, color='blue')
plt.xlabel('Programming Languages')
plt.ylabel('Popularity')
plt.title('Popularity of Programming Languages')

plt.show()

# %%
#Svitlana
from matplotlib import pyplot
num=[29,16,8.7,6.7]
labels=['Python','Java','JavaScript','C#']
pos=list(range(4))
colors=['blue','red','black','purple']
pyplot.bar(pos,num,color=colors)
pyplot.xticks(ticks=pos, labels=labels)
pyplot.title('Programming Language Popularity')
pyplot.ylabel('Share %')
pyplot.xlabel('Language')
pyplot.show()
